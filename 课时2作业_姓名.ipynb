# %% [markdown]
# 基本语法操作如下：
#
# # 1. 一级标题
# ## 1.2. 二级标题
# ### 1.2.3. 三级标题
#
# - 无序列表，用'-'表示
# - 无序列表，用'-'表示
# - 无序列表，用'-'表示
#
# 1. 有序列表，用数字表示
# 2. 有序列表，用数字表示
# 3. 有序列表，用数字表示
#
# **加粗**，用两个星号表示
#
# *斜体*，用一个星号表示
#
# [超链接](https://www.kaggle.com/)
#
# 代码高亮`code`，用反引号表示
#
# 行内公式 $a^2 + b^2 = c^2$，用单个美元符号夹着表示；
#
# 块级公式：$$a^2 + b^2 = c^2 \tag{1}$$，用两个美元符号表示，后面的\tag{}用于显示公式编号。
#
# 以上内容都是后续学习latex的基础，后续会有更详细的学习。

# %%
# 写下你的代码
import numpy as np

# ... your code here ...

# %% [markdown]
# # 接下来是才是作业模板，完成作业后请删掉前面两个示例的单元以及本段内容

# %% [markdown]
# # 1. 问题一求解
# ## 1.1. 问题重述
# （这里用你的语言重新描述问题，不要直接复制内容）
#
# ## 1.2. 问题分析
# （这里用你的语言分析问题，突出你对这个问题内容的关注点）
#
# ## 1.3. 模型建立
#
# 这里需要你表达你建立的模型，一般需要有描述，有图表，有公式，有图表更好。（详细可以用CL(Ctrl+L)或官网GPT解决）
#
# ### 1.3.1. ...（写下你的小标题，例如你解这道题有三个步骤，这里写第一个步骤的名字）
#
# 下面是表示公式的一个例子，注意等号的左边的字母要在公式的前面，等号的右边的字母要在公式的后面（其中，...的后面）。
#
#
# 根据勾股定理，直角三角形的斜边$c$可以表示为：
# $$c = \sqrt{a^2 + b^2} \tag{1}$$
# 其中，$a$和$b$分别是直角三角形的两条直角边。
#
# 这里是
#
# ### 1.3.2. ...（和前面同理）
#
# ### ...（如果有更多步骤，继续写下去）
#
#
# # 2. 问题二求解
